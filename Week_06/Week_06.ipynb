# %%
import requests
from bs4 import BeautifulSoup as bs
naver_movie = requests.get("https://movie.naver.com/movie/point/af/list.nhn?target=after").text
naver_movie_obj = bs(naver_movie,"html.parser")
naver_movie = naver_movie_obj.find('tbody')
movie_review = naver_movie.find_all('tr')
count_ = len(movie_review)

# %%
print (movie_review[0].find('td',class_ = 'point').text)
print (movie_review[0].find('a',class_ = 'movie').text)

review_content = movie_review[0].find('a',class_ = 'report').get('href')

start = review_content.find('(')
end = review_content.find(')')
start_point = review_content[start + 1:end]
list_ = start_point.split(',')
review = list_[2]
print (review)
# Out:
# 1
# 기생충
#  '&amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸역 극장으로 와서 관객수나 채워&amp;#39;란 식의 알바들 태도가 맘에 안 들어서 평점 조정 들어감. 실제론 5.5~6점 영화. 보고 나면 기분 더럽고 하루가 불쾌함. 같이 본 사람이랑 싸우게 됨.'

# %%
for i in range(count_):
    print (movie_review[i].find('td',class_ = 'point').text)
    print (movie_review[i].find('a',class_ = 'movie').text)

    review_content = movie_review[i].find('a',class_ = 'report').get('href')

    start = review_content.find('(')
    end = review_content.find(')')
    start_point = review_content[start + 1:end]
    list_ = start_point.split(',')
    review = list_[2]
    print(review)
# Out:
# 1
# 기생충
#  '&amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸역 극장으로 와서 관객수나 채워&amp;#39;란 식의 알바들 태도가 맘에 안 들어서 평점 조정 들어감. 실제론 5.5~6점 영화. 보고 나면 기분 더럽고 하루가 불쾌함. 같이 본 사람이랑 싸우게 됨.'
# 10
# 클레멘타인
#  '감동 그자체네요...눈물이 멈추질않습니다'
# 10
# 알라딘
#  '진짜 취향저격 영화였어요 ㅠㅠ 노래도 너무 좋고 너무 예쁘고 좋았어요 !!'
# 10
# 어벤져스: 엔드게임
#  '너무너무 대 존잼 ㅜㅜ 또 보고싶으뮤ㅠㅠㅠ'
# 10
# 맨 인 블랙: 인터내셔널
#  '원래 이런 영화는 웃기기만 하면됨'
# 2
# 0.0MHz
#  '내가 본 공포영화중에 제일 최악'
# 10
# 러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
#  '3학년이 졸업해도 아쿠아는 끝나지 않는다는걸 알려준 영화'
# 10
# 기생충
#  '작품성이 뛰어난 영화 참 재미있게 잘 봤습니다.'
# 2
# 기생충
#  '이거15세라뇨.   15세안본는거좋아요.    처음인데 끝나고.  기분이상합니다.   영화보고 기분좋아야되는대.    이상합니다.    평보고. 너무현실라고하는대.    저는라니라고봅니다'
# 10
# 기생충
#  '대중적인 오락영화는 아니었고 관람등급에도 의문은 가지만 깊이 있게 세상에 대해 생각해볼 수 있는 의미 있는 영화네요'

# %%
result_score = []
result_title = []
result_review = []
for i in range(count_):
    result_score.append(movie_review[i].find('td',class_ = 'point').text)
    result_title.append(movie_review[i].find('a',class_ = 'movie').text)

    review_content = movie_review[i].find('a',class_ = 'report').get('href')

    start = review_content.find('(')
    end = review_content.find(')')
    start_point = review_content[start + 1:end]
    list_ = start_point.split(',')
    review = list_[2]
    result_review.append(review)

# %%
data = {'score':result_score,'title':result_title,'report':result_review}
print(data)
# Out:
# {'score': ['1', '10', '10', '10', '10', '2', '10', '10', '2', '10'], 'title': ['기생충', '클레멘타인', '알라딘', '어벤져스: 엔드게임', '맨 인 블랙: 인터내셔널', '0.0MHz', '러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우', '기생충', '기생충', '기생충'], 'report': [" '&amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸역 극장으로 와서 관객수나 채워&amp;#39;란 식의 알바들 태도가 맘에 안 들어서 평점 조정 들어감. 실제론 5.5~6점 영화. 보고 나면 기분 더럽고 하루가 불쾌함. 같이 본 사람이랑 싸우게 됨.'", " '감동 그자체네요...눈물이 멈추질않습니다'", " '진짜 취향저격 영화였어요 ㅠㅠ 노래도 너무 좋고 너무 예쁘고 좋았어요 !!'", " '너무너무 대 존잼 ㅜㅜ 또 보고싶으뮤ㅠㅠㅠ'", " '원래 이런 영화는 웃기기만 하면됨'", " '내가 본 공포영화중에 제일 최악'", " '3학년이 졸업해도 아쿠아는 끝나지 않는다는걸 알려준 영화'", " '작품성이 뛰어난 영화 참 재미있게 잘 봤습니다.'", " '이거15세라뇨.   15세안본는거좋아요.    처음인데 끝나고.  기분이상합니다.   영화보고 기분좋아야되는대.    이상합니다.    평보고. 너무현실라고하는대.    저는라니라고봅니다'", " '대중적인 오락영화는 아니었고 관람등급에도 의문은 가지만 깊이 있게 세상에 대해 생각해볼 수 있는 의미 있는 영화네요'"]}

# %%
import pandas as pd
dt = pd.DataFrame(data,columns = ['score','title','report'])
dt
# Out:
#   score                                title  \
# 0     1                                  기생충
# 1    10                                클레멘타인
# 2    10                                  알라딘
# 3    10                           어벤져스: 엔드게임
# 4    10                        맨 인 블랙: 인터내셔널
# 5     2                               0.0MHz
# 6    10  러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 7    10                                  기생충
# 8     2                                  기생충
# 9    10                                  기생충
#
#                                               report
# 0   '&amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸...
# 1                           '감동 그자체네요...눈물이 멈추질않습니다'
# 2        '진짜 취향저격 영화였어요 ㅠㅠ 노래도 너무 좋고 너무 예쁘고 좋았어요 !!'
# 3                          '너무너무 대 존잼 ㅜㅜ 또 보고싶으뮤ㅠㅠㅠ'
# 4                               '원래 이런 영화는 웃기기만 하면됨'
# 5                                '내가 본 공포영화중에 제일 최악'
# 6                  '3학년이 졸업해도 아쿠아는 끝나지 않는다는걸 알려준 영화'
# 7                       '작품성이 뛰어난 영화 참 재미있게 잘 봤습니다.'
# 8   '이거15세라뇨.   15세안본는거좋아요.    처음인데 끝나고.  기분이상합니다...
# 9   '대중적인 오락영화는 아니었고 관람등급에도 의문은 가지만 깊이 있게 세상에 대해 ...

# %%
page_num = int(input('크롤링 할 페이지 수: '))

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

result_score = []
result_title = []
result_review = []
result_id = []


for page in range(1,page_num):
    naver_movie_url = "https://movie.naver.com/movie/point/af/list.nhn?page=" + str(page)
    naver_movie = requests.get(naver_movie_url).text
    naver_movie_obj = bs(naver_movie,"html.parser")
    naver_movie = naver_movie_obj.find('tbody')
    movie_review = naver_movie.find_all('tr')
    

    for i in range(10):
        result_score.append(movie_review[i].find('td',class_ = 'point').text)
        result_title.append(movie_review[i].find('a',class_ = 'movie').text)
        result_id.append(movie_review[i].select('td')[4].find('a').text)

        review_content = movie_review[i].find('a',class_ = 'report').get('href')

        start = review_content.find('(')
        end = review_content.find(')')
        start_point = review_content[start + 1:end]
        list_ = start_point.split(',')
        review = list_[2]
        result_review.append(review)
data = {'id':result_id,'score':result_score,'title':result_title,'report':result_review}
dt = pd.DataFrame(data,columns = ['id','score','title','report'])
# Out:
# 크롤링 할 페이지 수: 8
#           id score                                title  \
# 0   veb2****    10                        맨 인 블랙: 인터내셔널
# 1   i1ny****    10                        맨 인 블랙: 인터내셔널
# 2   x0by****    10                        맨 인 블랙: 인터내셔널
# 3   imso****     4                        맨 인 블랙: 인터내셔널
# 4   bt4q****    10                        맨 인 블랙: 인터내셔널
# 5   i22e****    10                        맨 인 블랙: 인터내셔널
# 6   cyb0****    10                        맨 인 블랙: 인터내셔널
# 7   wmi5****     9                        맨 인 블랙: 인터내셔널
# 8   xtnt****    10                        맨 인 블랙: 인터내셔널
# 9   patr****     4                        맨 인 블랙: 인터내셔널
# 10  lyhf****     2                        맨 인 블랙: 인터내셔널
# 11  sang****     5                               콜드 체이싱
# 12  vhmd****    10                        맨 인 블랙: 인터내셔널
# 13  kf2m****    10                        맨 인 블랙: 인터내셔널
# 14  ralp****     5                          엑스맨: 다크 피닉스
# 15  yasp****    10                         평일 오후 3시의 연인
# 16  ralp****     8                                  기생충
# 17  kfen****     1                              명탐정 피카츄
# 18  kims****     1                                  기생충
# 19  yobo****    10                                클레멘타인
# 20  gnlu****    10                                  알라딘
# 21  seul****    10                           어벤져스: 엔드게임
# 22  yoqi****    10                        맨 인 블랙: 인터내셔널
# 23  dase****     2                               0.0MHz
# 24  love****    10  러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 25  urt0****    10                                  기생충
# 26  jimm****     2                                  기생충
# 27  shar****    10                                  기생충
# 28  ldm0****    10                             맨 인 블랙 3
# 29  derm****     6                                  기생충
# ..       ...   ...                                  ...
# 40  itsk****     6                          엑스맨: 다크 피닉스
# 41  sunu****    10                                  알라딘
# 42  l0v2****     7                                킬링 디어
# 43  es75****     8                                 업사이드
# 44  dark****    10                              빌리 엘리어트
# 45  ehdr****     1                        맨 인 블랙: 인터내셔널
# 46  enel****     9                                  범블비
# 47  zwsd****    10                        맨 인 블랙: 인터내셔널
# 48  enel****     9                                  알라딘
# 49  ekef****    10                        맨 인 블랙: 인터내셔널
# 50  gucg****    10                        맨 인 블랙: 인터내셔널
# 51  husu****     1                               0.0MHz
# 52  1004****    10                                  알라딘
# 53  enel****     5                          엑스맨: 다크 피닉스
# 54  siwo****     6                        맨 인 블랙: 인터내셔널
# 55  1004****    10                                  기생충
# 56  netd****     1                        맨 인 블랙: 인터내셔널
# 57  ck_m****    10                        극장판 오소마츠 6쌍둥이
# 58  rodw****     4                        맨 인 블랙: 인터내셔널
# 59  plmy****     1                                   버닝
# 60  chll****     8                          엑스맨: 다크 피닉스
# 61  popp****    10                                  알라딘
# 62  wnrf****    10                               미스 슬로운
# 63  chrh****     1                                 업사이드
# 64  kimh****     1                          엑스맨: 다크 피닉스
# 65  hyun****     1                                  기생충
# 66  qhdw****     2                                  악인전
# 67  limp****    10                                  글래스
# 68  plmy****    10                                위시 어폰
# 69  sunj****    10                                  알라딘
#
#                                                report
# 0                                      '잼잇어요 ㅎㅎ 너무조아'
# 1                                      '옛날코미디 영화 생각남'
# 2                                '오오.. 햄식이한테 또 반함 ㅎㅎ'
# 3                            '별 두개 준이유 포니가 귀여워서내용은 ㅋ'
# 4                                    '머리비우기 괜찮은 영화~~'
# 5                              'B급 코미디 영화로는 적당한 것 같다'
# 6                                '햄식이 얼굴이 너무 재밌잖아...'
# 7                                     '은근 웃기고 재밌음 ㅎㅎ'
# 8                            '머리쓰지 않고 봐도 되서 좋은 것 같아요'
# 9    '내가 초딩3학년때쯤 봤다면 재밌다고 느꼈을 유치함과 그저 주연만.바뀌었을뿐 예전...
# 10                       '큰기대하지마세요평점 높은게 이해 안되네요..ㅠㅠ'
# 11                        '코믹도 아니고 영화도 아니고 뭔지 잘 모르겠다'
# 12                                          '새로운 맨인블랙
# 13                                 '그냥 가볍게 볼 수 있는 영화'
# 14                         '엑스맨 시리즈 중에서는 제일 재미없네요...'
# 15   '이성만으로 설명할 수 없는 사랑과 감정에 대한 이야기를 담담하게 출어냈다. 막장...
# 16   '이해할 수도 있는 스토리... 하지만  일반적이지 않은 내용이네요. 물론 영화이...
# 17         '주인공이 영락없는 흑인+흑인 출신인데 아버지가 라이언레이놀즈고 ㅈㄹ ^^'
# 18   '&amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸...
# 19                           '감동 그자체네요...눈물이 멈추질않습니다'
# 20        '진짜 취향저격 영화였어요 ㅠㅠ 노래도 너무 좋고 너무 예쁘고 좋았어요 !!'
# 21                          '너무너무 대 존잼 ㅜㅜ 또 보고싶으뮤ㅠㅠㅠ'
# 22                               '원래 이런 영화는 웃기기만 하면됨'
# 23                                '내가 본 공포영화중에 제일 최악'
# 24                  '3학년이 졸업해도 아쿠아는 끝나지 않는다는걸 알려준 영화'
# 25                       '작품성이 뛰어난 영화 참 재미있게 잘 봤습니다.'
# 26   '이거15세라뇨.   15세안본는거좋아요.    처음인데 끝나고.  기분이상합니다...
# 27   '대중적인 오락영화는 아니었고 관람등급에도 의문은 가지만 깊이 있게 세상에 대해 ...
# 28                                   '마!!이게 맨인블랙이다!!'
# 29                      '주제가 뭔지 혼란스러움  보고나서 기분 안좋은 영'
# ..                                                ...
# 40                            '그냥  볼만한 영화  끝장면이  아쉬움'
# 41                         '쟈스민의 스피치리스 독백신 자체는 경이로웠지만
# 42                          '뭔가 불편했슴. 내용이 잘 생각안나지만..'
# 43   '시사회로 봤는데 감동보다는 개그요소가 더 많은 영화였던 것 같아요~ 그래도 마지...
# 44                                 '내 생애 잊혀지지않는 인생영화'
# 45                                  '감독이 이렇게 중요합니다..'
# 46                                 '아이들이 좋아해요 재밌습니다.'
# 47                            '영화 재밌었고 햄식이 진짜 섹시해요ㅠㅠ'
# 48              '아이들과 함께 보러갔다가 정신 쏙 팔려서 보았네요 너무 재밌어요'
# 49                                      '병맛 코미디인가???'
# 50                           '아 저몸에 수트 안어울리면 반칙이지 ㅋㅋ'
# 51                             '은지야 미안하다 이번만은 어쩔수없다.'
# 52                                  '가볍게 즐겁게 보기 좋습니다'
# 53                                    '볼거리는 많네요 볼거리는'
# 54   '윌스미스와 토미리존스가 그리운건 왜일까요? 맨인블랙의 특유의 코미디와 내용을 잘...
# 55                                           '비주얼과 연출
# 56        '원작에 미안해질 정도의 각본에 페미까지 묻어서 제2의 창궐급의 괴작이 나옴'
# 57        '시사 보고 왔어여ㅠㅠㅠㅠ미쳤음 더빙도 얼른 개보유ㅠㅠㅠ주차별 특전 다 내꺼'
# 58                                  '이거 평점 왜이리 높지...'
# 59                        '이게 무슨 공포 영화야 공포스릴러라해서 봤더니'
# 60          '엑스맨 팬으로써 이번작품 상당히재미있게봤습니다 메그니토의 간지란....'
# 61   '공주 알라딘 지니 캐스팅 완벽 눈 귀 가 즐거운 황홀한 영화 윌스미스는 퇴물이 ...
# 62                                     '최고의 영화 인생영화임'
# 63   '씁.. 정말좋아하던 영화였는데 이렇게 망가질줄이야.. 원작에 비해 하나도 안웃기...
# 64                             '감독 무슨기준으로 뽑지? 페미기준인가'
# 65                 '그닥 보고나면 생각과 해석이 난무하지만 영화자체는 별로였다'
# 66                               '김규리연기완전못한다ㅋㅋ영화망쳣네ㅋ'
# 67                                '전작들 다 보고서 평가해라 ;;'
# 68                             '이거 진짜 무섭고 재밋다 교훈도 있고'
# 69                                    '명작명작?? 내 인생영화'
#
# [70 rows x 4 columns]

# %%
dt.to_csv('/Users/hankiho/Desktop/df_result.csv', index = False, encoding = "utf-8-sig")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-36673dcb6ee0> in <module>
# ----> 1 dt
#
# NameError: name 'dt' is not defined
