# %%
import pandas as pd

# %%
dt = pd.read_csv('/Users/hankiho/Desktop/movie_review.csv')

# %%
dt.head() # 상위 5개만 볼 수 있는 함수
# Out:
#          id  score          title  \
# 0  choa****      9            알라딘
# 1  vill****      2  맨 인 블랙: 인터내셔널
# 2  tana****     10         어린 의뢰인
# 3  lyin****     10         어린 의뢰인
# 4  ozin****      2  맨 인 블랙: 인터내셔널
#
#                                               report
# 0   아이랑 봐야해서 더빙판으로 봤는데자스민공주역의 뮤지컬배우님정말 찰떡이더라구요~아주...
# 1                                    완전 병맛  드럽게 재미없음
# 2                     도저히 못 보 겠다.이 죄 값 을 어떻게 치울래....
# 3                                현대사회에 있어 타인에 대한 존중
# 4                                    노잼? 얘들 수준 영화 실망

# %%
len (dt) # 데이터 길이를 확인 할 수 있는 함수
# Out:
# 10000

# %%
dt['id'].head() #한개의 Feature를 인덱싱한는 방법, 리스트랑 비슷하다고 보면된다.
# Out:
# 0    choa****
# 1    vill****
# 2    tana****
# 3    lyin****
# 4    ozin****
# Name: id, dtype: object

# %%
dt['id'].nunique() #고유값 확인 방법
# Out:
# 6930

# %%
dt['title'].value_counts().head(7) #attribute들의 갯수들을 확인하는 방법
# Out:
# 기생충              2141
# 알라딘              1464
# 맨 인 블랙: 인터내셔널    1168
# 엑스맨: 다크 피닉스       659
# 걸캅스               403
# 0.0MHz            199
# 어벤져스: 엔드게임        162
# Name: title, dtype: int64

# %%
dt[dt['title'] == '기생충'] #특정 attribute만 인덱싱 하는 방법
parasite = dt[dt['title'] == '기생충']

# %%
print ('평균 평점은: ', parasite['score'].mean())
print ('최저 평점은: ', parasite['score'].min())
print ('최고 평점은: ', parasite['score'].max())
# Out:
# 평균 평점은:  8.274638019617
# 최저 평점은:  1
# 최고 평점은:  10

# %%
parasite[(parasite['score'] == 1) | (parasite['score'] == 2)]
# Out:
#             id  score title                                             report
# 21    elva****      1   기생충                              여지껏 보다가 재미없어서 나온적은 처음
# 60    engi****      1   기생충            현실을 반영단다고 하기엔 영화적 표현과 과장에  그리 공감하지 못하겠다
# 85    dkmt****      1   기생충   안보길 잘 했다. 상타고 바로 다음 주 개봉하는 것 보고 볼 필요가 없는 작품이라...
# 119   jssh****      1   기생충                                      아주 기분 나빠지는 영화
# 126   wond****      2   기생충                이건 절대 청불용이다  등급 먹인넘 과 감독이  제정신이 아니다
# 152   supe****      1   기생충                    댓글이나 평점은 믿을게 못된다는걸 새삼 느끼게 해준...
# 188   tree****      2   기생충   평점이 너무 높다부자들도 더티해보이고  가난한사람들더 더욱 더티하게 그린...훌륭...
# 297   smsa****      1   기생충                  제발 한국영화로 영화관 독점 좀 하지마... 알라딘 좀 보자
# 546   scri****      2   기생충                                      생각보다 재미 없습니다.
# 719   kims****      1   기생충   &amp;#39;높으신 분들이 높은 상 주면 너네 같은 기생충 개돼지들은 꾸역꾸역...
# 726   jimm****      2   기생충   이거15세라뇨.   15세안본는거좋아요.    처음인데 끝나고.  기분이상합니다....
# 764   hyun****      1   기생충                   그닥 보고나면 생각과 해석이 난무하지만 영화자체는 별로였다
# 779   chsu****      2   기생충                          이런 영화가 세상에 안좋은 영향만 미칠듯합니다
# 792   ally****      1   기생충   어떤 좌빨놈의 말 &amp;#34;우린 보수삥뜯어 평생놀고먹을거야.&amp;#34...
# 796   snt1****      1   기생충                                 평론가들평점은 거르는게 답이네
# 864   jjun****      2   기생충   봉준호는 살아오면서 가난한 적이 있었는지 진심 물어보고 싶다. 지독한 가난을 겪어...
# 893   fsoo****      1   기생충                               뻔한 메시지. 쓸데없고 불필요한 장면
# 894   1124****      1   기생충                                5점 정도인데 평점이 넘높아서 1점
# 905   rain****      2   기생충                        아들 데리고 갔다가 얼굴 화끈거리구 쫌 그랬어요ㅠ
# 1100  chi3****      2   기생충   주인공이라 볼 수 있는 기생충들의 사고방식을 나로서는 이해할 수 없음. 가난을 빌...
# 1121  lyc0****      2   기생충                           기대가 너무 컸네~ 뒤끝이 개운치 않은 영화
# 1253  gg59****      2   기생충            솔직하게 재미없다 난거짓말안한다내말들어라ㅋ끝까지 집중해서보긴했지만답없다
# 1277  na40****      1   기생충    어우 빈부격차?뭔가 의미전달하는데 있어서라이트하게 전달해주면 좋겠어요너무 심오해요..
# 1349  qldr****      1   기생충                            15세라는게 참.. 19세로 올리시죠...
# 1385  yell****      1   기생충                     대중들은 개돼지가 맞는듯.. 1점은 아닌데 9점도 아님
# 1424  jojo****      1   기생충   연출이 자연스럽지 못하고 매우 작위적임. 외국서 상 탔다고 그저 좋은줄 아는 수백...
# 1498  hond****      2   기생충                                     왜재미없다고 말을못해...
# 1652  jsjs****      2   기생충                               이게 재미 있어요? 진짜 재미있어요?
# 1691  roba****      1   기생충        오늘 심야보러 갔다가 예매하는도중에 여친이랑 싸우고헤어졌다 잊지않으마 기생충
# 1704  khy7****      2   기생충                   보고난후 옆자리에 앉아있던 고등학생 얼굴봤을때 민망했음..
# ...        ...    ...   ...                                                ...
# 8946  wjdg****      1   기생충                                   왜? 왜지 왤까 와 이게...
# 8949  aaa3****      1   기생충   개연성 구멍이 너무 많고 결국 말하고자 하는 메시지가 뭔지 모르겠다. 그냥 블랙코...
# 9050  cosm****      2   기생충                                       15세관람가로  부적격
# 9141  nm12****      2   기생충                      솔 직히잼없다  감동도  재미도없다  다큐좋아하는사람
# 9146  2and****      1   기생충   야 이 시발 이렇게 잔인한 내용을 어떻게 15세 관람으로 해놓냐. 내 앞 좌석은 ...
# 9147  jang****      1   기생충   가난하면불법을저질러도되고 부자가착한건 돈이많아서라는건가?가난하면 범죄를저지를수밖에...
# 9154  bsw4****      1   기생충   기대 많이하고 관람했는데후회 많이 했습니다.지금까지 영화보고 실망하기는처음이내요....
# 9172  euge****      1   기생충   그냥 알라딘 볼걸.. 미성년자랑 성인이 사귀는 설정은 진짜 불쾌했다. 영화 다보고...
# 9194  wjsd****      1   기생충   스토리도 진짜 별로고 성희롱은 일상이며 미자성인 키스씬이 대체 왜 나오는지 모르겠...
# 9217  x1k1****      1   기생충                                 보면서 난 만원이 아깝다고 생각함
# 9228  cmhe****      2   기생충               재있어질라다가 어느 지점부터 보기 불편하고 뭔 개소린가싶음. 별로
# 9259  soso****      2   기생충              정말 별로였어요.극단적으로 표현하는 방법..이제 조금 바꿔야 할듯.
# 9323  powe****      2   기생충             빈과 부를 정확히 표현못했다좀더 근단적인 가난과 부가 표현되었어야한다
# 9328  desi****      2   기생충                            취향차가 심함... 너무 반지하 냄새남..
# 9428  nowt****      1   기생충                   굉장히 불편했고 찝찝했음 철학조차 개인적으로 별로 안맞았다
# 9447  choi****      2   기생충       진짜 보고나서 이렇게 기분 나쁜 영화는 처음이에요..왜 호평을 받는지 모르겠네요
# 9449  clfg****      1   기생충                                  찝찝하고?기분나쁘고 실망이예요?
# 9460  fixe****      1   기생충                                최악. 고구마 백개 물없이 먹는기분
# 9490  dona****      1   기생충        차라리 알라딘을 보는게 정신건강에 좋음 알라딘은 재밋기라도 하지 이건 머 ..
# 9495  dodo****      2   기생충                      반미주의자   봉준호      민중당 지지자  봉준호
# 9509  jaem****      2   기생충   아~~정말 최악~!보고나서 관람객들 아무말 없이 표정 굳은채 나가더라!!이걸 보려...
# 9609  itop****      1   기생충   솔직히 유명배우와 봉감독 깐느 아니고 비인기 감독과 평범한 배우들 하고 개봉했으면...
# 9615  lew3****      1   기생충          최근 몇년 본 영화 중 젤 별로였어요 ㅜㅜ 들킬까 말까 아슬아슬한 그 상황
# 9810  athe****      1   기생충                            욕참기 실패  절대 한국영화 다신안봄 수고
# 9845  dark****      1   기생충                                      나만 재미없던건가....
# 9864  acek****      2   기생충     솔직히 진짜 재미없었다. 끝나고 극장 다수사람들이 실망이 많았다 살인의추억2나 찍지
# 9868  boap****      1   기생충                                     처음엔 좋았다.재미도 있고
# 9869  cecy****      1   기생충   좌파  봉준호식 계급 투쟁 영화 연속편... 가진자는 죄인이고 범죄자라는 공산주의...
# 9876  kaf_****      2   기생충   가난하지만 양심있고 올바르게 사는 사람들도 많은데 영화 전반적으로 가난한사람의 생...
# 9920  hpcs****      1   기생충                             평점이 넘 높다 남는게 하나도 없는 영화
#
# [238 rows x 4 columns]

# %%
parasite.loc[(parasite['score'] > 5)]
# Out:
#             id  score title                                             report
# 6     bebe****      8   기생충                                       2시간 시간 순삭이네요
# 16    bebe****      8   기생충                                       2시간 시간 순삭이네요
# 25    scv4****     10   기생충                             꿀잼 ~ 오랜만에 재미있는 영화본 듯해용
# 34    tmda****     10   기생충                                     밋밋한듯 가장 화려한 영화
# 36    wlsg****     10   기생충                영화가 끝났을때 나는 약 10초간 아무런 생각도 할수가 없었다.
# 47    xian****     10   기생충   영화를 보고나니 가슴속에 돌맹이 하나 엊어놓은듯합니다. 현실적인 한국사회라고할까요...
# 51    naka****     10   기생충   두번봤는데 처음봤을때랑 또다른 해석이 되네요 왜봉테일 하는지 알겠어요처음볼땐 송강...
# 55    jaym****     10   기생충                                 말로 표현할 수 없는 묘한 긴장감
# 68    powe****     10   기생충    보고 나와서 남들에게 스포없이 설명할때 장르를 말할수가 없는 영화....장르: 봉준호
# 91    lcol****     10   기생충                                        또보고싶어요최고입니다
# 100   illk****     10   기생충     이영화 보면서 갑자기 정의당 생각이 났다 민주당에 붙어 기생하는 기생충 같단 생각이
# 104   hane****     10   기생충   빈부격차의 충돌된 면을 보여주는 것 같습니다. 선정적인 면이 오히려 보기 안 좋습...
# 118   grun****     10   기생충                                     절로 고개가 숙여지는 영화
# 125   olta****      9   기생충         볼만했다.. 그런데 이게 황금종려상이라고??? 칸도 수준이 많이 낮아졌네..
# 133   athi****      9   기생충     이유있는 씁쓸한 뒷맛.  오만가지 생각이 다 들었으면 좋겠다는 감독의 의도는 성공!
# 162   yags****      8   기생충                                   가볍지만은 않은 영화였어요~~
# 166   marl****     10   기생충                                역시 올바른 방향은 시계방향 입니다
# 169   choy****     10   기생충                  재미도 있으면서~생각하게 하는 영화~봉테일의 섬세함을 느끼다
# 177   dlru****      6   기생충                                             오늘 봤는데
# 178   s309****     10   기생충                                     워낙 유명한 영화니 스포도
# 186   ehqh****      8   기생충                                       vdfve2123fds
# 193   bhki****      7   기생충                                 다소 충격적이고 씁쓸한 블랙코미디
# 199   sell****     10   기생충                                       정말 기발한 스토리^^
# 202   cact****      8   기생충                                     잘 봤습니다. 재밌었어요.
# 215   rlar****      9   기생충                                재밌음/ 봉중호다움/조여정의 재발견
# 218   daew****     10   기생충   불편했다. 중반부터는 도저히 보기 힘들어서 핸드폰을 만지작거렸다. 그럼에도 일주일...
# 226   hiem****     10   기생충                          기생충에 나온 모든 배우들 흥하시길 바랍니다!
# 230   flcd****     10   기생충                            최근 본 영화중에 제일 신선한 영화였습니다
# 232   miyo****      6   기생충   절대 청소년과 같이 볼 영화수중은 아닙니당애들하고 보다 딱 한장면이지만 15세 관...
# 235   silv****     10   기생충   나에게서는 어떤 냄새가 날까??? 누군가의 냄새에 난 눈살을 찌푸린 적이 없었던가???
# ...        ...    ...   ...                                                ...
# 9844  roya****     10   기생충                            인생은 멀리서보면 희극 가까이서 보면 비극
# 9847  whdl****     10   기생충                                     최고의 시나리오!! 입니다
# 9852  proj****     10   기생충                              갓띵작 rnasterpiece ㄱl생충
# 9854  thdc****     10   기생충                                잼게봤어요 엄마라우한번 볼만한듯 ㅋ
# 9856  myyo****     10   기생충   찝찝하다고들 하는데 원래 저런 컨셉의 작품을 보려고 간거라 난 너무 재미있었음. ...
# 9858  wing****     10   기생충                      참담하고 현실적이다.다시한번 보고싶은 무게감있는영화.
# 9875  psj3****     10   기생충   정말 재밌고 잘 만들었는데 다신 보고싶지 않은 영화.. 영화 전반적인 분위기가 너...
# 9890  ihom****     10   기생충                              보고나서 기분 묘함 코미디에서 스릴러로
# 9891  chee****     10   기생충               드럽고 끝이 쓰디쓰고 불쾌함이 내내 가시질 않는 이시대의 명작이다
# 9897  kjl_****      8   기생충    저거 미제야! 불우이웃끼리 돕고살아요. 난  불우이웃 아니야!  이게  자꾸  ...
# 9911  many****     10   기생충   설국열차보다 더 커진 격차. 그리고 닿을 수 없는 꿈. 무계획이 가장 정확한 삶의...
# 9922  sky_****     10   기생충                                       재미있습니다~~~1~~
# 9925  eee6****     10   기생충                                      여운이 계속 남는 영화.
# 9930  jmgo****      8   기생충                               부부가 볼만한 영화이나 권장은 그다지
# 9934  vivi****      8   기생충   호평을 받았지만 난  잘  모르겠다.  특히 꽤 쎈 내용이라서 심약한 사람들은 보...
# 9937  ojw2****     10   기생충                                 간만에 나온 수준 높은 퀄리티..
# 9941  odol****      7   기생충                           재미있어요. 제가 좋아하는 한국적 컬러에요.
# 9942  a118****      9   기생충                    보다 찝찝하고 그 어떤 주인공에게도 공감할 수 있는 영화
# 9949  akam****     10   기생충                                       생각할거리가 많은 영화
# 9952  crui****     10   기생충                                    아주 아주 재밌네요 강추에요
# 9953  euns****      8   기생충                                    재밌었지만 결말이 너무 쑈킹
# 9966  2005****      8   기생충   처음에는  그냥 빈부격차가  심하다 생각하면서  봤지만 영화말미부터는   씁쓸하다...
# 9970  tktm****     10   기생충   전반부는한 명씩 한 명씩 기생해가며 잔잔하게 흘러간다 하지만 초인종 소리가 들리고...
# 9971  skh1****      9   기생충                            기생충을 알아버린 공생충의 좌충우돌 드라마
# 9972  qwna****     10   기생충                         잘짜여진 영화 오랜만에 봐서 재밌게 보고왔어요~
# 9976  leed****     10   기생충   진짜 소름이네 ㅋㅋ 평점 10짜리는 싫어요 누르고1~3짜리는 좋아요 눌러주네 ㅋㅋ...
# 9978  quee****     10   기생충                                      너무재미잇게잘봣습니다역시
# 9983  na72****     10   기생충                             단 한장면도 필름이 아까운 씬이 없었음.
# 9994  shan****     10   기생충                           여과없는 현실의 반영이라는 사실이 충격적.
# 9999  linn****     10   기생충        캐릭터 하나하나 연기구멍이란 없는영화..이 영화가 15세 관람가는 아닌거같다~
#
# [1825 rows x 4 columns]

# %%
import seaborn as sns
sns.distplot(parasite["score"], bins = 20, color = "b")

# %%
sns.countplot(data = parasite, x = 'score')

# %%
dt[(dt['title'] == '기생충') | (dt['title'] == '걸캅스')]
# Out:
#             id  score title                                             report
# 6     bebe****      8   기생충                                       2시간 시간 순삭이네요
# 16    bebe****      8   기생충                                       2시간 시간 순삭이네요
# 21    elva****      1   기생충                              여지껏 보다가 재미없어서 나온적은 처음
# 25    scv4****     10   기생충                             꿀잼 ~ 오랜만에 재미있는 영화본 듯해용
# 34    tmda****     10   기생충                                     밋밋한듯 가장 화려한 영화
# 36    wlsg****     10   기생충                영화가 끝났을때 나는 약 10초간 아무런 생각도 할수가 없었다.
# 47    xian****     10   기생충   영화를 보고나니 가슴속에 돌맹이 하나 엊어놓은듯합니다. 현실적인 한국사회라고할까요...
# 51    naka****     10   기생충   두번봤는데 처음봤을때랑 또다른 해석이 되네요 왜봉테일 하는지 알겠어요처음볼땐 송강...
# 55    jaym****     10   기생충                                 말로 표현할 수 없는 묘한 긴장감
# 57    dugm****      3   기생충                       잔인하고 걍글이다....마지막 결말이 충격적인 영화
# 60    engi****      1   기생충            현실을 반영단다고 하기엔 영화적 표현과 과장에  그리 공감하지 못하겠다
# 68    powe****     10   기생충    보고 나와서 남들에게 스포없이 설명할때 장르를 말할수가 없는 영화....장르: 봉준호
# 85    dkmt****      1   기생충   안보길 잘 했다. 상타고 바로 다음 주 개봉하는 것 보고 볼 필요가 없는 작품이라...
# 91    lcol****     10   기생충                                        또보고싶어요최고입니다
# 100   illk****     10   기생충     이영화 보면서 갑자기 정의당 생각이 났다 민주당에 붙어 기생하는 기생충 같단 생각이
# 104   hane****     10   기생충   빈부격차의 충돌된 면을 보여주는 것 같습니다. 선정적인 면이 오히려 보기 안 좋습...
# 116   ohmy****      3   기생충                      기자 평론가들이 빨고 있어서 기자 평론가 들이 우숩다
# 118   grun****     10   기생충                                     절로 고개가 숙여지는 영화
# 119   jssh****      1   기생충                                      아주 기분 나빠지는 영화
# 125   olta****      9   기생충         볼만했다.. 그런데 이게 황금종려상이라고??? 칸도 수준이 많이 낮아졌네..
# 126   wond****      2   기생충                이건 절대 청불용이다  등급 먹인넘 과 감독이  제정신이 아니다
# 133   athi****      9   기생충     이유있는 씁쓸한 뒷맛.  오만가지 생각이 다 들었으면 좋겠다는 감독의 의도는 성공!
# 145   suns****      1   걸캅스                          알바 너무 심하네... 로긴하게 만드네....
# 152   supe****      1   기생충                    댓글이나 평점은 믿을게 못된다는걸 새삼 느끼게 해준...
# 162   yags****      8   기생충                                   가볍지만은 않은 영화였어요~~
# 166   marl****     10   기생충                                역시 올바른 방향은 시계방향 입니다
# 169   choy****     10   기생충                  재미도 있으면서~생각하게 하는 영화~봉테일의 섬세함을 느끼다
# 177   dlru****      6   기생충                                             오늘 봤는데
# 178   s309****     10   기생충                                     워낙 유명한 영화니 스포도
# 186   ehqh****      8   기생충                                       vdfve2123fds
# ...        ...    ...   ...                                                ...
# 9880  blue****      1   걸캅스             제가 살다가 처음으로 댓글다는데..정말 평점이 9점대인 영환가요..?
# 9886  my71****      1   걸캅스                                  시대가 낳은 괴작 그리고 괴흥행
# 9890  ihom****     10   기생충                              보고나서 기분 묘함 코미디에서 스릴러로
# 9891  chee****     10   기생충               드럽고 끝이 쓰디쓰고 불쾌함이 내내 가시질 않는 이시대의 명작이다
# 9892  jihu****     10   걸캅스           성지순례왔습니다. 여기가 영화보기전에 재밋다라고 평남기는 곳인가요 ㅋㅋㅋ
# 9897  kjl_****      8   기생충    저거 미제야! 불우이웃끼리 돕고살아요. 난  불우이웃 아니야!  이게  자꾸  ...
# 9911  many****     10   기생충   설국열차보다 더 커진 격차. 그리고 닿을 수 없는 꿈. 무계획이 가장 정확한 삶의...
# 9913  yown****     10   걸캅스                        진짜 재밌어요 !!! 시간가는줄 모르고 봤어요ㅎㅎ
# 9920  hpcs****      1   기생충                             평점이 넘 높다 남는게 하나도 없는 영화
# 9922  sky_****     10   기생충                                       재미있습니다~~~1~~
# 9924  hype****      5   기생충   이 영화는 결국 무례한 영화다. 연출은 훌륭하다고 하지만 가난한 사람을 결국 기생...
# 9925  eee6****     10   기생충                                      여운이 계속 남는 영화.
# 9930  jmgo****      8   기생충                               부부가 볼만한 영화이나 권장은 그다지
# 9934  vivi****      8   기생충   호평을 받았지만 난  잘  모르겠다.  특히 꽤 쎈 내용이라서 심약한 사람들은 보...
# 9937  ojw2****     10   기생충                                 간만에 나온 수준 높은 퀄리티..
# 9941  odol****      7   기생충                           재미있어요. 제가 좋아하는 한국적 컬러에요.
# 9942  a118****      9   기생충                    보다 찝찝하고 그 어떤 주인공에게도 공감할 수 있는 영화
# 9949  akam****     10   기생충                                       생각할거리가 많은 영화
# 9952  crui****     10   기생충                                    아주 아주 재밌네요 강추에요
# 9953  euns****      8   기생충                                    재밌었지만 결말이 너무 쑈킹
# 9966  2005****      8   기생충   처음에는  그냥 빈부격차가  심하다 생각하면서  봤지만 영화말미부터는   씁쓸하다...
# 9970  tktm****     10   기생충   전반부는한 명씩 한 명씩 기생해가며 잔잔하게 흘러간다 하지만 초인종 소리가 들리고...
# 9971  skh1****      9   기생충                            기생충을 알아버린 공생충의 좌충우돌 드라마
# 9972  qwna****     10   기생충                         잘짜여진 영화 오랜만에 봐서 재밌게 보고왔어요~
# 9976  leed****     10   기생충   진짜 소름이네 ㅋㅋ 평점 10짜리는 싫어요 누르고1~3짜리는 좋아요 눌러주네 ㅋㅋ...
# 9978  quee****     10   기생충                                      너무재미잇게잘봣습니다역시
# 9983  na72****     10   기생충                             단 한장면도 필름이 아까운 씬이 없었음.
# 9984  kimj****      1   걸캅스   까메오와 주조연을 바꿨으면.. 감상후기:최수영연기 재밌음.  형사가된 복주. 모델...
# 9994  shan****     10   기생충                           여과없는 현실의 반영이라는 사실이 충격적.
# 9999  linn****     10   기생충        캐릭터 하나하나 연기구멍이란 없는영화..이 영화가 15세 관람가는 아닌거같다~
#
# [2544 rows x 4 columns]

# %%
dt_01 = dt[(dt['title'] == '0.0MHz') | (dt['title'] == '어벤져스: 엔드게임')]

# %%
sns.countplot(data = dt_01, x = 'score', hue = 'title')

# %%
pd.DataFrame(dt.groupby('title')['score'].mean()).sort_values(by = 'score', ascending = False)
# Out:
#                score
# title
# 쇼생크 탈출          10.0
# 산이 울다           10.0
# 포커스             10.0
# 뷰티플 마인드         10.0
# 블라인드 사이드        10.0
# 블랙 스완           10.0
# 블랙 스완: 흑화       10.0
# 블레이드 러너 2049    10.0
# 비밀은 없다          10.0
# 비밀의 숲           10.0
# 평행이론            10.0
# 빅 베어            10.0
# 빅뱅 메이드          10.0
# 빌리 엘리어트         10.0
# 사도              10.0
# 사라진 밤           10.0
# 사랑              10.0
# 사랑은 비가 갠 뒤처럼    10.0
# 페르디난드           10.0
# 사랑의 기적          10.0
# 사랑이 이긴다         10.0
# 뷰티풀 마인드         10.0
# 뷰티 인사이드         10.0
# 불꽃 슛 통키         10.0
# 보통사람            10.0
# 베스와 베라          10.0
# 베오울프            10.0
# 베일리 어게인         10.0
# 벤허              10.0
# 변호인             10.0
# ...              ...
# 무현, 두 도시 이야기     1.0
# 몰리스 게임           1.0
# 실화: 숨겨진 비밀       1.0
# 메리다와 마법의 숲       1.0
# 메가로돈             1.0
# 맨체스터 바이 더 씨      1.0
# 매트리악             1.0
# 매직 아워            1.0
# 맛있는 택배           1.0
# 마터스: 천국을 보는 눈    1.0
# 배틀쉽              1.0
# 베로니카의 이중 생활      1.0
# 베스트셀러            1.0
# 변산               1.0
# 신세계              1.0
# 슬리퍼스             1.0
# 스테이션 7           1.0
# 설리: 허드슨강의 기적     1.0
# 서양골동양과자점 앤티크     1.0
# 퍼시픽 림: 업라이징      1.0
# 살아남은 아이          1.0
# 사일런트 힐           1.0
# 페넬로피             1.0
# 사마리아             1.0
# 사관과 신사           1.0
# 비포 미드나잇          1.0
# 비긴 어게인           1.0
# 폴라 익스프레스         1.0
# 붉은 가족            1.0
# 히스테리아            1.0
#
# [1409 rows x 1 columns]

# %%
parasite['report']
# Out:
# 6                                            2시간 시간 순삭이네요
# 16                                           2시간 시간 순삭이네요
# 21                                  여지껏 보다가 재미없어서 나온적은 처음
# 25                                 꿀잼 ~ 오랜만에 재미있는 영화본 듯해용
# 34                                         밋밋한듯 가장 화려한 영화
# 36                    영화가 끝났을때 나는 약 10초간 아무런 생각도 할수가 없었다.
# 47       영화를 보고나니 가슴속에 돌맹이 하나 엊어놓은듯합니다. 현실적인 한국사회라고할까요...
# 51       두번봤는데 처음봤을때랑 또다른 해석이 되네요 왜봉테일 하는지 알겠어요처음볼땐 송강...
# 55                                     말로 표현할 수 없는 묘한 긴장감
# 57                           잔인하고 걍글이다....마지막 결말이 충격적인 영화
# 60                현실을 반영단다고 하기엔 영화적 표현과 과장에  그리 공감하지 못하겠다
# 68        보고 나와서 남들에게 스포없이 설명할때 장르를 말할수가 없는 영화....장르: 봉준호
# 85       안보길 잘 했다. 상타고 바로 다음 주 개봉하는 것 보고 볼 필요가 없는 작품이라...
# 91                                            또보고싶어요최고입니다
# 100        이영화 보면서 갑자기 정의당 생각이 났다 민주당에 붙어 기생하는 기생충 같단 생각이
# 104      빈부격차의 충돌된 면을 보여주는 것 같습니다. 선정적인 면이 오히려 보기 안 좋습...
# 116                         기자 평론가들이 빨고 있어서 기자 평론가 들이 우숩다
# 118                                        절로 고개가 숙여지는 영화
# 119                                         아주 기분 나빠지는 영화
# 125            볼만했다.. 그런데 이게 황금종려상이라고??? 칸도 수준이 많이 낮아졌네..
# 126                   이건 절대 청불용이다  등급 먹인넘 과 감독이  제정신이 아니다
# 133        이유있는 씁쓸한 뒷맛.  오만가지 생각이 다 들었으면 좋겠다는 감독의 의도는 성공!
# 152                       댓글이나 평점은 믿을게 못된다는걸 새삼 느끼게 해준...
# 162                                      가볍지만은 않은 영화였어요~~
# 166                                   역시 올바른 방향은 시계방향 입니다
# 169                     재미도 있으면서~생각하게 하는 영화~봉테일의 섬세함을 느끼다
# 177                                                오늘 봤는데
# 178                                        워낙 유명한 영화니 스포도
# 186                                          vdfve2123fds
# 188      평점이 너무 높다부자들도 더티해보이고  가난한사람들더 더욱 더티하게 그린...훌륭...
#                               ...
# 9868                                       처음엔 좋았다.재미도 있고
# 9869     좌파  봉준호식 계급 투쟁 영화 연속편... 가진자는 죄인이고 범죄자라는 공산주의...
# 9870                                   잼없다 그냥 티비에 나오면 보세요
# 9875     정말 재밌고 잘 만들었는데 다신 보고싶지 않은 영화.. 영화 전반적인 분위기가 너...
# 9876     가난하지만 양심있고 올바르게 사는 사람들도 많은데 영화 전반적으로 가난한사람의 생...
# 9890                                보고나서 기분 묘함 코미디에서 스릴러로
# 9891                 드럽고 끝이 쓰디쓰고 불쾌함이 내내 가시질 않는 이시대의 명작이다
# 9897      저거 미제야! 불우이웃끼리 돕고살아요. 난  불우이웃 아니야!  이게  자꾸  ...
# 9911     설국열차보다 더 커진 격차. 그리고 닿을 수 없는 꿈. 무계획이 가장 정확한 삶의...
# 9920                               평점이 넘 높다 남는게 하나도 없는 영화
# 9922                                         재미있습니다~~~1~~
# 9924     이 영화는 결국 무례한 영화다. 연출은 훌륭하다고 하지만 가난한 사람을 결국 기생...
# 9925                                        여운이 계속 남는 영화.
# 9930                                 부부가 볼만한 영화이나 권장은 그다지
# 9934     호평을 받았지만 난  잘  모르겠다.  특히 꽤 쎈 내용이라서 심약한 사람들은 보...
# 9937                                   간만에 나온 수준 높은 퀄리티..
# 9941                             재미있어요. 제가 좋아하는 한국적 컬러에요.
# 9942                      보다 찝찝하고 그 어떤 주인공에게도 공감할 수 있는 영화
# 9949                                         생각할거리가 많은 영화
# 9952                                      아주 아주 재밌네요 강추에요
# 9953                                      재밌었지만 결말이 너무 쑈킹
# 9966     처음에는  그냥 빈부격차가  심하다 생각하면서  봤지만 영화말미부터는   씁쓸하다...
# 9970     전반부는한 명씩 한 명씩 기생해가며 잔잔하게 흘러간다 하지만 초인종 소리가 들리고...
# 9971                              기생충을 알아버린 공생충의 좌충우돌 드라마
# 9972                           잘짜여진 영화 오랜만에 봐서 재밌게 보고왔어요~
# 9976     진짜 소름이네 ㅋㅋ 평점 10짜리는 싫어요 누르고1~3짜리는 좋아요 눌러주네 ㅋㅋ...
# 9978                                        너무재미잇게잘봣습니다역시
# 9983                               단 한장면도 필름이 아까운 씬이 없었음.
# 9994                             여과없는 현실의 반영이라는 사실이 충격적.
# 9999          캐릭터 하나하나 연기구멍이란 없는영화..이 영화가 15세 관람가는 아닌거같다~
# Name: report, Length: 2141, dtype: object

# %%
df_review = str(parasite['report'])
df_review
# Out:
# '6                                            2시간 시간 순삭이네요\n16                                           2시간 시간 순삭이네요\n21                                  여지껏 보다가 재미없어서 나온적은 처음\n25                                 꿀잼 ~ 오랜만에 재미있는 영화본 듯해용\n34                                         밋밋한듯 가장 화려한 영화\n36                    영화가 끝났을때 나는 약 10초간 아무런 생각도 할수가 없었다.\n47       영화를 보고나니 가슴속에 돌맹이 하나 엊어놓은듯합니다. 현실적인 한국사회라고할까요...\n51       두번봤는데 처음봤을때랑 또다른 해석이 되네요 왜봉테일 하는지 알겠어요처음볼땐 송강...\n55                                     말로 표현할 수 없는 묘한 긴장감\n57                           잔인하고 걍글이다....마지막 결말이 충격적인 영화\n60                현실을 반영단다고 하기엔 영화적 표현과 과장에  그리 공감하지 못하겠다\n68        보고 나와서 남들에게 스포없이 설명할때 장르를 말할수가 없는 영화....장르: 봉준호\n85       안보길 잘 했다. 상타고 바로 다음 주 개봉하는 것 보고 볼 필요가 없는 작품이라...\n91                                            또보고싶어요최고입니다\n100        이영화 보면서 갑자기 정의당 생각이 났다 민주당에 붙어 기생하는 기생충 같단 생각이\n104      빈부격차의 충돌된 면을 보여주는 것 같습니다. 선정적인 면이 오히려 보기 안 좋습...\n116                         기자 평론가들이 빨고 있어서 기자 평론가 들이 우숩다\n118                                        절로 고개가 숙여지는 영화\n119                                         아주 기분 나빠지는 영화\n125            볼만했다.. 그런데 이게 황금종려상이라고??? 칸도 수준이 많이 낮아졌네..\n126                   이건 절대 청불용이다  등급 먹인넘 과 감독이  제정신이 아니다\n133        이유있는 씁쓸한 뒷맛.  오만가지 생각이 다 들었으면 좋겠다는 감독의 의도는 성공!\n152                       댓글이나 평점은 믿을게 못된다는걸 새삼 느끼게 해준...\n162                                      가볍지만은 않은 영화였어요~~\n166                                   역시 올바른 방향은 시계방향 입니다\n169                     재미도 있으면서~생각하게 하는 영화~봉테일의 섬세함을 느끼다\n177                                                오늘 봤는데\n178                                        워낙 유명한 영화니 스포도\n186                                          vdfve2123fds\n188      평점이 너무 높다부자들도 더티해보이고  가난한사람들더 더욱 더티하게 그린...훌륭...\n                              ...                        \n9868                                       처음엔 좋았다.재미도 있고\n9869     좌파  봉준호식 계급 투쟁 영화 연속편... 가진자는 죄인이고 범죄자라는 공산주의...\n9870                                   잼없다 그냥 티비에 나오면 보세요\n9875     정말 재밌고 잘 만들었는데 다신 보고싶지 않은 영화.. 영화 전반적인 분위기가 너...\n9876     가난하지만 양심있고 올바르게 사는 사람들도 많은데 영화 전반적으로 가난한사람의 생...\n9890                                보고나서 기분 묘함 코미디에서 스릴러로\n9891                 드럽고 끝이 쓰디쓰고 불쾌함이 내내 가시질 않는 이시대의 명작이다\n9897      저거 미제야! 불우이웃끼리 돕고살아요. 난  불우이웃 아니야!  이게  자꾸  ...\n9911     설국열차보다 더 커진 격차. 그리고 닿을 수 없는 꿈. 무계획이 가장 정확한 삶의...\n9920                               평점이 넘 높다 남는게 하나도 없는 영화\n9922                                         재미있습니다~~~1~~\n9924     이 영화는 결국 무례한 영화다. 연출은 훌륭하다고 하지만 가난한 사람을 결국 기생...\n9925                                        여운이 계속 남는 영화.\n9930                                 부부가 볼만한 영화이나 권장은 그다지\n9934     호평을 받았지만 난  잘  모르겠다.  특히 꽤 쎈 내용이라서 심약한 사람들은 보...\n9937                                   간만에 나온 수준 높은 퀄리티..\n9941                             재미있어요. 제가 좋아하는 한국적 컬러에요.\n9942                      보다 찝찝하고 그 어떤 주인공에게도 공감할 수 있는 영화\n9949                                         생각할거리가 많은 영화\n9952                                      아주 아주 재밌네요 강추에요\n9953                                      재밌었지만 결말이 너무 쑈킹\n9966     처음에는  그냥 빈부격차가  심하다 생각하면서  봤지만 영화말미부터는   씁쓸하다...\n9970     전반부는한 명씩 한 명씩 기생해가며 잔잔하게 흘러간다 하지만 초인종 소리가 들리고...\n9971                              기생충을 알아버린 공생충의 좌충우돌 드라마\n9972                           잘짜여진 영화 오랜만에 봐서 재밌게 보고왔어요~\n9976     진짜 소름이네 ㅋㅋ 평점 10짜리는 싫어요 누르고1~3짜리는 좋아요 눌러주네 ㅋㅋ...\n9978                                        너무재미잇게잘봣습니다역시\n9983                               단 한장면도 필름이 아까운 씬이 없었음.\n9994                             여과없는 현실의 반영이라는 사실이 충격적. \n9999          캐릭터 하나하나 연기구멍이란 없는영화..이 영화가 15세 관람가는 아닌거같다~\nName: report, Length: 2141, dtype: object'

# %%
#특수문자와 숫자 제거
import re

def cleanText(readData):
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', readData)
    return text

def cleanNumber(readData):
    text = re.sub('[0-9]', '', readData)
    return text

# %%
import nltk
from konlpy.tag import Twitter; t = Twitter()
# Out:
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
# 특수문자, 숫자 제거 후 토큰화
tokens_ko = t.morphs(cleanNumber(cleanText(df_review)))

# %%
stop_words = ['가','요','을','수','에','제','를','이','도','닉네임','입니다','된',
              '좋','는','로','으로','것','은','다','니다','대','들','이라','네','n',
              '들','데','의','때','겠','고','게','네요','한','일','할','\n','r',
              '하는','주','려고','인데','거','좀','는데','전','이라','했','주려','t',
              '뭐','까','있는','습니다','다면','했','주려','무지','합니다','에서','\\','\xa0'
              '지','있','못','후','중','줄','과','에서','해','단어','라고','합','부터']
tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(30)
# Out:
# [('영화', 25),
#  ('적', 8),
#  ('\n     ', 8),
#  ('생각', 7),
#  ('없는', 7),
#  ('처음', 5),
#  ('사람', 5),
#  ('시간', 4),
#  ('만', 4),
#  ('\n                                         ', 4),
#  ('하나', 4),
#  ('인', 4),
#  ('잘', 4),
#  ('\n                                        ', 4),
#  ('평점', 4),
#  ('이네', 3),
#  ('\n       ', 3),
#  ('현실', 3),
#  ('\n        ', 3),
#  ('볼', 3),
#  ('기생', 3),
#  ('\n      ', 3),
#  ('아주', 3),
#  ('\n                                      ', 3),
#  ('\n                                   ', 3),
#  ('재미', 3),
#  ('너무', 3),
#  ('가난한', 3),
#  ('전반', 3),
#  ('순삭', 2)]

# %%
from wordcloud import WordCloud
wc = WordCloud(font_path = '/Users/hankiho/anaconda3/lib/python3.6/site-packages/pytagcloud/fonts/NanumBarunGothic.ttf',
              background_color='white', max_words=2000, stopwords = stop_words)
wc = wc.generate(df_review) #스트링으로 변환해야됨

plt.figure(figsize=(8,8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
